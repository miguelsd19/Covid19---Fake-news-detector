# %%
import pandas as pd
archivo= "covid.csv"

df= pd.read_csv(archivo, names=['created_at','text','retweet_count', 'favorite_count', 'lang', 'user', 'user id', 'user followers', 'possibly sensitive'])
#df=df.drop([0],axis=0)
df.head()
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3229: DtypeWarning: Columns (2,3,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         created_at                                               text  \
# 0       created_at                                               text
# 1  10/19/2021 0:24  â€œThe plaintiffs ignore the harm that their r...
# 2  10/19/2021 0:22  RT @blf_tv: ðŸ›‘ðŸ‘‰ðŸ½ Ã€ la sortie du centr...
# 3  10/19/2021 0:16  RT @cassandra17lina: Donâ€™t feel guilty about...
# 4  10/19/2021 0:05  RT @wqbelle: The enemy is us.\n\nhttps://t.co/...
#
#    retweet_count  favorite_count  lang  \
# 0  retweet_count  favorite_count  lang
# 1              0               1    en
# 2              5               0    fr
# 3              4               0    en
# 4             59               0    en
#
# ...

# %%
eng = df[df.lang =='en']
eng.head()
# Out:
#          created_at                                               text  \
# 1   10/19/2021 0:24  â€œThe plaintiffs ignore the harm that their r...
# 3   10/19/2021 0:16  RT @cassandra17lina: Donâ€™t feel guilty about...
# 4   10/19/2021 0:05  RT @wqbelle: The enemy is us.\n\nhttps://t.co/...
# 7   10/19/2021 0:00  #SouthAfrica  #antivax  #antimandate  #protest...
# 8  10/18/2021 23:59  RT @cassandra17lina: Donâ€™t feel guilty about...
#
#   retweet_count favorite_count lang  \
# 1             0              1   en
# 3             4              0   en
# 4            59              0   en
# 7             0              1   en
# 8             4              0   en
#
#                                                 user     user id  \
# 1                                          DigBoston    20257508
# 3  Tuggmunkee ðŸ‘»ðŸŽƒHOST BODY FullyVaxxed/Still...  1741856767
# 4                                     JFSebastian146  1729193269
# ...

# %%
eng=eng.drop(['created_at', 'possibly sensitive'], axis=1)

# %%
eng.duplicated()
# Out:
# 1         False
# 3         False
# 4         False
# 7         False
# 8         False
#           ...
# 133523    False
# 133524    False
# 133525    False
# 133526    False
# 133527    False
# Length: 83387, dtype: bool

# %%
eng=eng.drop_duplicates()

# %%
eng.head()
# Out:
#                                                 text retweet_count  \
# 1  â€œThe plaintiffs ignore the harm that their r...             0
# 3  RT @cassandra17lina: Donâ€™t feel guilty about...             4
# 4  RT @wqbelle: The enemy is us.\n\nhttps://t.co/...            59
# 7  #SouthAfrica  #antivax  #antimandate  #protest...             0
# 8  RT @cassandra17lina: Donâ€™t feel guilty about...             4
#
#   favorite_count lang                                               user  \
# 1              1   en                                          DigBoston
# 3              0   en  Tuggmunkee ðŸ‘»ðŸŽƒHOST BODY FullyVaxxed/Still...
# 4              0   en                                     JFSebastian146
# 7              1   en                                      á¤olt Phonic
# 8              0   en                                                BDB
#
#       user id user followers
# 1    20257508          41477
# 3  1741856767          12126
# 4  1729193269          11971
# ...

# %%
#eng.to_csv('datasetENG.csv')

# %%
eng[eng.text.str.contains('plandemic')]
# Out:
#                                                      text retweet_count  \
# 1432    RT @Partangel12: @NickPye10 @JOHjohJOH12 They'...            15
# 1435    RT @Partangel12: @NickPye10 @JOHjohJOH12 They'...            15
# 1438    RT @timfprice: 2022 - to watch the public exec...             1
# 1442    RT @ChrissyvTyranny: Aussie MP Ryan Smith resp...            12
# 1444    RT @sarfsee: this is "legal" murder by Aussy p...            40
# ...                                                   ...           ...
# 133468  RT @NVPatriotGirl: This ðŸ‘‡ðŸ»ðŸ‘‡ðŸ»ðŸ‘‡ðŸ...            19
# 133469  RT @NVPatriotGirl: This ðŸ‘‡ðŸ»ðŸ‘‡ðŸ»ðŸ‘‡ðŸ...            19
# 133471  RT @NVPatriotGirl: This ðŸ‘‡ðŸ»ðŸ‘‡ðŸ»ðŸ‘‡ðŸ...            19
# 133472  This ðŸ‘‡ðŸ»ðŸ‘‡ðŸ»ðŸ‘‡ðŸ»\n\n#scamdemic #p...            19
# 133497  RT @RoryTDC: WOW!!! This is huge. How many mor...             1
#
#        favorite_count lang                                               user  \
# ...

# %%
eng[eng.text.str.contains('experimental')]
# Out:
#                                                      text retweet_count  \
# 1142    Again raising the question as to what medical ...             0
# 1791    To erâ€™body hammering on those who wonâ€™t ge...             0
# 3014    2 of my young friends have died just shortly a...             0
# 6952    RT @MossSwan: Reclaim your power.\nSay no to a...             1
# 11040   RT @MossSwan: Reclaim your power.\nSay no to a...             1
# ...                                                   ...           ...
# 130158  RT @meat_sheet: Stuff that is cool.\n https://...             7
# 130171  buying this for only 1usd on #Bandcamp you're ...             2
# 130173  RT @meat_sheet: Stuff that is cool.\n https://...             7
# 130174  Let us know your ideaðŸ’« #experimental #NFTar...             0
# 133515  These things were also apparent during the #sc...             0
#
#        favorite_count lang                user      user id user followers
# ...

# %%
eng[eng.text.str.contains('novax')]
# Out:
#                                                      text retweet_count  \
# 3651    Karma is a BxxchðŸ’¥ #novax #triesteportuali h...             0
# 4637    In the future I see @novax_game @IslandsOfAvax...             0
# 6157    @AmericanAir give it up #novax #NoVaccineManda...             0
# 6166    No school, no work, no travel, and no ? They w...             0
# 23191   @mathowie @PatC iâ€™m gonna get sputnik AND si...             0
# 29097   @el33th4xor Avalanche have @novax_game play to...             0
# 29305             Per i #novax \n https://t.co/3QNclQTUoT             0
# 29795   @UFTScotland Simply atrocious child abuse if n...             0
# 29836      @FreedomFatherUS Guess I won't by dying #novax             0
# 29896   They're taking our rights! They'll never touch...             0
# 29900                  @Lisaonthesofa #novax welcome here             0
# 43663   @erikcats The #novax / bigots just found that ...             0
# ...

# %%
eng[eng.text.str.contains('god')]
# Out:
#                                                      text retweet_count  \
# 1703    @B52Malmet My god that tells you how irrespons...             0
# 2759    RT @hrIykoo: oh my god in south korea itâ€™s a...          2330
# 5102    RT @AhmedBaba_: I finally just watched that Tu...          1439
# 15352   @plzhelpmynolez @godfeare @MichaelBerrySho I d...             0
# 17122   This is for all the Pakistani Govt die hard fa...             0
# ...                                                   ...           ...
# 125552  RT @haramcart: All the media says is vaccines,...             2
# 126252  All the media says is vaccines, omicron, war i...             2
# 127957  @samanthaagodwin @marypatriott The last thing ...             0
# 129768  Guess I will be having a March release after a...             0
# 130362  Funny NOT funny!  ðŸ¤£ðŸ™„ðŸ¥´\n\n#dowhatlight...             0
#
#        favorite_count lang                              user      user id  \
# ...

# %%
eng[eng.text.str.contains('jesus')]
# Out:
#                                                      text retweet_count  \
# 5396    RT @gboslovesjesus: At the United Center, you ...            82
# 33353   RT @gboslovesjesus: Texas Father Who Lost 16-Y...           371
# 33417   RT @gboslovesjesus: Texas Father Who Lost 16-Y...           371
# 33600   RT @gboslovesjesus: Texas Father Who Lost 16-Y...           371
# 66124   RT @gboslovesjesus: Since the plandemic began,...             2
# 74999   RT @BrianCShort: [for sine and formant wave, a...             1
# 75003   [for sine and formant wave, acoustic &amp; ele...             1
# 94227   @gboslovesjesus Plandemic will end with a succ...             0
# 118514  @gboslovesjesus Supposedly two people I know.....             0
# 118765  @gboslovesjesus ðŸ¤£ðŸ¤£ðŸ¤£ðŸ¤£ðŸ¤£ðŸ¤£ðŸ¤£\n...             0
# 119221  RT @jesuschic4life: How do you cause mass depo...             4
# 119268  @gboslovesjesus As many as unvaccinated...Plan...             0
# ...

# %%
eng[eng.text.str.contains('5G')]
# Out:
#                                                      text retweet_count  \
# 2911    @Whatz_InA_Name @sarahbeth345 Very true people...             0
# 6117    Eish I now have 5G at my house, it could be th...             0
# 9644    @JamaicaGleaner How is this news?Please preach...             0
# 9848    Exactly!!âœ…ðŸ’¯ðŸ’¥\nFrauds out to make a Dol...             0
# 12421   @JoanNoxWilson More Vitamin D would be great! ...             0
# ...                                                   ...           ...
# 129974  RT @RST_PhD: Have you heard â€˜Magicry of Mist...             1
# 129975  Have you heard â€˜Magicry of Mistsâ€™ by @RST_...             1
# 130504  As a person with a hearing loss myself, the mo...             0
# 131312  @PotomacDaily @thehill Oh, look...another (min...             0
# 131594  Being tired of a pandemic instead of learning ...             0
#
#        favorite_count lang                   user      user id user followers
# ...

# %%
eng[eng.text.str.contains('Masks')]
# Out:
#                                                      text retweet_count  \
# 1320    @DrGuddiSingh @GMB @itvstudios @DrAmirKhanGP @...             0
# 2945    @CBSLA People are getting fed-up with the stup...             0
# 7019    RT @HSHQ: LOVE ON TOUR. SHOP MERCH EARLY.\nTue...           834
# 7022    RT @HSHQ: LOVE ON TOUR. SHOP MERCH EARLY.\nTue...           834
# 7028    RT @HSHQ: LOVE ON TOUR. SHOP MERCH EARLY.\nTue...           834
# ...                                                   ...           ...
# 130769  RT @neoskeptics: "New C.D.C. Guidelines Sugges...             1
# 130808  "New C.D.C. Guidelines Suggest 70 Percent of A...             1
# 131333  What would you do if this happened? ðŸ¤”ðŸ¤”\n...             0
# 131707  RT @IndisputableTYT: FL surgeon general: Masks...             6
# 131797  RT @IndisputableTYT: FL surgeon general: Masks...             6
#
#        favorite_count lang                                               user  \
# ...

# %%
eng[eng.text.str.contains('man-made')]
# Out:
#                                                      text retweet_count  \
# 124889  @megynkelly In case some people don't know by ...             0
#
#        favorite_count lang               user   user id user followers
# 124889              0   en  George A Henry Jr  1.45e+18              0

# %%
eng[eng.text.str.contains('mental|control')]
# Out:
#                                                      text retweet_count  \
# 1142    Again raising the question as to what medical ...             0
# 1222    #Membranes\nExperimental Study on a Ceramic Me...             0
# 1430    @beckyschnitty When will we learn whoâ€™s in c...             0
# 1432    RT @Partangel12: @NickPye10 @JOHjohJOH12 They'...            15
# 1435    RT @Partangel12: @NickPye10 @JOHjohJOH12 They'...            15
# ...                                                   ...           ...
# 131863  Have the fundamentals of your #Business change...             0
# 132155  RT @ROHRIngya: Coping with mental health durin...             2
# 132499  RT @China4Tech: COVID19 pandemic control perso...            14
# 133344  So many people already lost so much from the b...             0
# 133515  These things were also apparent during the #sc...             0
#
#        favorite_count lang                                               user  \
# ...

# %%
eng[eng.user == 'George A Henry Jr']
# Out:
#                                                      text retweet_count  \
# 124889  @megynkelly In case some people don't know by ...             0
# 124894  @MarciaM16952337 @gerihair10 @megynkelly Lady ...             0
#
#        favorite_count lang               user   user id user followers
# 124889              0   en  George A Henry Jr  1.45e+18              0
# 124894              3   en  George A Henry Jr  1.45e+18              0

# %%
eng1=eng.astype(str)
eng1.sort_values(by="user followers",ascending=False)
# Out:
#                                                      text retweet_count  \
# 110504  RT @nycgov: If you attended the Anime NYC 2021...            18
# 102960  RT @jameyedwards: "The #pandemic made clear th...            22
# 118122  RT @moorela66180327: I have been working all t...           461
# 102804  ðŸ˜­I have tested positive for covidðŸ˜­\n\nOn...             0
# 40325   Zero tolerance vs. "learning to live with" #CO...             0
# ...                                                   ...           ...
# 115168  #Plandemic is starting to sound a lot like #Sc...             0
# 60214   RT @disclosetv: JUST IN - Pfizer CEO: People w...           446
# 1430    @beckyschnitty When will we learn whoâ€™s in c...             0
# 48435   @aartipole @CBCNews NO and the plandemic what ...             0
# 99499   RT @DOTSWAVES_TV: â–™The silent twins who prod...            34
#
#        favorite_count lang                  user       user id user followers
# ...

# %%
eng2=eng1[eng1.text.str.contains('plandemic')]
eng2=eng2.astype(str)
eng2.sort_values(by="user followers",ascending=False)
# Out:
#                                                      text retweet_count  \
# 118122  RT @moorela66180327: I have been working all t...           461
# 36285   RT @btaylor_71: If I was writing the #NJ scene...             9
# 58293   RT @Lee351T: The beginning of the plandemic,i ...           193
# 120681  So you psychologically tortured your child int...             0
# 15076   RT @bluefirerising: @healthfirst500 This is a ...             9
# ...                                                   ...           ...
# 9973    @LisaMarieBoothe The sarcasm perpetuates the p...             0
# 57209   So Gates is not happy making billions on his c...             0
# 117587  @cafreeland You are a lying as well. So when i...             0
# 94339   @SallyBundockBBC @BBCOne @BBCNews @BBCWorld Lo...             0
# 17553   @DrEliDavid Should be referred to as "plandemi...             2
#
#        favorite_count lang                         user       user id  \
# ...

# %%
#In the word plandemic
eng2.sort_values(by="retweet_count",ascending=False)
# Out:
#                                                      text retweet_count  \
# 14891   RT @SarahPlumleyUK: Over 20 months into a "dea...           981
# 16865   RT @SarahPlumleyUK: Over 20 months into a "dea...           981
# 15118   RT @SarahPlumleyUK: Over 20 months into a "dea...           981
# 36133   RT @NewWor1d0rder: Remember this?ðŸ‘‡ they've ...            97
# 58185   RT @SoldierMil: @castterry73 If the government...            95
# ...                                                   ...           ...
# 81831   @ProgressiveTex @RepThomasMassie How crazy lib...             0
# 119297                 @DrEliDavid What a worse plandemic             0
# 119302  @Doshi13 @Zack4DJT Ivermectin has been freely ...             0
# 81816   @goodeliberal201 @GBNEWS Well they're firing u...             0
# 97109   A thread worth reading to open your eyes abt t...             0
#
#        favorite_count lang                       user       user id  \
# ...

# %%
#In the word plandemic
eng2.sort_values(by="favorite_count",ascending=False)
# Out:
#                                                      text retweet_count  \
# 65829   @conspiracyb0t Kary Mulis was one of the most ...            44
# 65871   @McGiff Get rid of your tv, radio, newspapers ...             6
# 119399  The @bis_org banking hard on the "plandemic" t...             0
# 36070   where in a fucking plandemic dude and you're j...             1
# 17728   @benonwine *sense* ðŸ‘ˆgone out the window sin...             3
# ...                                                   ...           ...
# 66390   RT @karenalainehunt: Since day one of this pla...             6
# 66379   RT @ClickyBuzz_c2c: @IndianOblivious Here it i...             1
# 66370       RT @Walt84346447: @DrEliDavid â€œplandemicâ€             1
# 66369   RT @MegaGreat1: Got the t-shirt te remember th...             8
# 133497  RT @RoryTDC: WOW!!! This is huge. How many mor...             1
#
#        favorite_count lang                                user       user id  \
# ...

# %%
eng[eng.user == 'LeBon Travel Culture']
# Out:
#                                                      text retweet_count  \
# 118122  RT @moorela66180327: I have been working all t...           461
#
#        favorite_count lang                  user      user id user followers
# 118122              0   en  LeBon Travel Culture  1.45267e+09           9996

# %%
eng[eng.user == 'Carl R. Tannenbaum']
# Out:
#                                                     text retweet_count  \
# 40325  Zero tolerance vs. "learning to live with" #CO...             0
# 63832  Fall weather is contributing to rising #COVID1...             0
#
#       favorite_count lang                user     user id user followers
# 40325              1   en  Carl R. Tannenbaum  4149739878           9992
# 63832              1   en  Carl R. Tannenbaum  4149739878           9990

# %%
eng[eng.user == 'ThePatriotist']
# Out:
#                                                      text retweet_count  \
# 115168  #Plandemic is starting to sound a lot like #Sc...             0
#
#        favorite_count lang           user   user id user followers
# 115168              0   en  ThePatriotist  1.47e+18              0

# %%
eng[eng.user == 'Bob Martin']
# Out:
#                                                     text retweet_count  \
# 48435  @aartipole @CBCNews NO and the plandemic what ...             0
#
#       favorite_count lang        user   user id user followers
# 48435              0   en  Bob Martin  1.45E+18              0
